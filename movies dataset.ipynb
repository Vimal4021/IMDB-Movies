# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Sahil Vimal\Desktop\imdb-top-1000.csv')
df
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes      Gross  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   int64
#  9   Metascore      843 non-null    float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Runtime            int64
# Genre             object
# IMDB_Rating      float64
# Director          object
# Star1             object
# No_of_Votes        int64
# Gross              int64
# Metascore        float64
# dtype: object

# %%
df.values
# Out:
# array([['The Shawshank Redemption', '1994', 142, ..., 2343110, 28341469,
#         80.0],
#        ['The Godfather', '1972', 175, ..., 1620367, 134966411, 100.0],
#        ['The Dark Knight', '2008', 152, ..., 2303232, 534858444, 84.0],
#        ...,
#        ['From Here to Eternity', '1953', 118, ..., 43374, 30500000, 85.0],
#        ['Lifeboat', '1944', 97, ..., 26471, 852142728, 78.0],
#        ['The 39 Steps', '1935', 86, ..., 51853, 302787539, 93.0]],
#       dtype=object)

# %%
dff=df.groupby('Genre')
dff.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
dff.corr()
# Out:
# C:\Users\Sahil Vimal\AppData\Local\Temp\ipykernel_9476\788259740.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.corr is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dff.corr()
#                       Runtime  IMDB_Rating  No_of_Votes     Gross  Metascore
# Genre
# Action  Runtime      1.000000     0.355538     0.209249  0.177618   0.187626
#         IMDB_Rating  0.355538     1.000000     0.557459  0.194019   0.261808
#         No_of_Votes  0.209249     0.557459     1.000000  0.239896   0.094101
#         Gross        0.177618     0.194019     0.239896  1.000000   0.059515
#         Metascore    0.187626     0.261808     0.094101  0.059515   1.000000
# ...                       ...          ...          ...       ...        ...
# Western Runtime      1.000000     0.755894     0.678277 -0.786664   0.797629
# ...

# %%
df.sample(5)
# Out:
#              Series_Title Released_Year  Runtime      Genre  IMDB_Rating  \
# 394        Kôkaku Kidôtai          1995       83  Animation          8.0
# 595          Kaze tachinu          2013      126  Animation          7.8
# 122   Ladri di biciclette          1948       89      Drama          8.3
# 93   Inglourious Basterds          2009      153  Adventure          8.3
# 740        Wreck-It Ralph          2012      101  Animation          7.7
#
#               Director                Star1  No_of_Votes      Gross  Metascore
# 394       Mamoru Oshii        Atsuko Tanaka       129231     515905       76.0
# 595     Hayao Miyazaki         Hideaki Anno        73690    5209580       83.0
# 122   Vittorio De Sica  Lamberto Maggiorani       146427     332930        NaN
# 93   Quentin Tarantino            Brad Pitt      1267869  120540719       69.0
# 740         Rich Moore       John C. Reilly       380195  189422889       72.0

# %%
#top five movies by revenue

df.groupby('Series_Title').max()['Gross'].sort_values(ascending=False).head(5)
# Out:
# Series_Title
# Star Wars: Episode VII - The Force Awakens    936662225
# Sholay                                        932069480
# Die Welle                                     924558264
# Bonnie and Clyde                              909838190
# Raazi                                         896910257
# Name: Gross, dtype: int64

# %%
#top genre by revenue
df.groupby('Genre')['Gross'].sum().sort_values(ascending=False).head(5)
# Out:
# Genre
# Drama        35409974041
# Action       32632261314
# Comedy       15663868165
# Animation    14631473048
# Adventure     9496922464
# Name: Gross, dtype: int64

# %%
#top genre by votes

df.groupby('Genre')['No_of_Votes'].sum().sort_values(ascending=False).head(5)
# Out:
# Genre
# Action       72282412
# Drama        61367304
# Crime        33533615
# Comedy       27620327
# Biography    24006844
# Name: No_of_Votes, dtype: int64

# %%
# find the highest rated movie of each genre
df.groupby('Genre')['IMDB_Rating'].max()
# Out:
# Genre
# Action       9.0
# Adventure    8.6
# Animation    8.6
# Biography    8.9
# Comedy       8.6
# Crime        9.2
# Drama        9.3
# Family       7.8
# Fantasy      8.1
# Film-Noir    8.1
# Horror       8.5
# Mystery      8.4
# Thriller     7.8
# Western      8.8
# Name: IMDB_Rating, dtype: float64

# %%
#top genre by metascore
df.groupby('Genre')['Metascore'].sum().sort_values(ascending=False)
# Out:
# Genre
# Drama        19208.0
# Action       10499.0
# Comedy        9840.0
# Crime         6706.0
# Animation     6082.0
# Biography     6023.0
# Adventure     5020.0
# Horror         880.0
# Mystery        633.0
# Western        313.0
# Film-Noir      287.0
# Family         158.0
# Thriller        81.0
# Fantasy          0.0
# Name: Metascore, dtype: float64

# %%
#top five movies by gross

df.groupby('Series_Title').max()['Gross'].sort_values(ascending=False).head(5).plot(title="Top Movies",xlabel="Movies_name",ylabel="Earning",kind='bar')
# Out:
# <Axes: title={'center': 'Top Movies'}, xlabel='Movies_name', ylabel='Earning'>

# %%
df.groupby('Genre').max()['Gross'].sort_values(ascending=False).head(5).plot(title="Top Genre",kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: title={'center': 'Top Genre'}, ylabel='Gross'>

# %%
#top five movies by IMDB rating
df[['Series_Title','IMDB_Rating']].head(5)
# Out:
#                Series_Title  IMDB_Rating
# 0  The Shawshank Redemption          9.3
# 1             The Godfather          9.2
# 2           The Dark Knight          9.0
# 3    The Godfather: Part II          9.0
# 4              12 Angry Men          9.0

# %%
#top five movies by IMDB rating
df.groupby('Series_Title').max()['IMDB_Rating'].sort_values(ascending=False).head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='Series_Title'>

# %%
#top five movies by revenue

df.groupby('Series_Title').max()['Gross'].sort_values(ascending=False).head(5).plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='Gross'>

# %%
#top five most profitable diretor 
df.groupby('Director')['Gross'].sum().sort_values(ascending=False).head(5)
# Out:
# Director
# Akira Kurosawa      3070431739
# Steven Spielberg    2478133165
# Hayao Miyazaki      2447324574
# Alfred Hitchcock    2337745776
# Anthony Russo       2205039403
# Name: Gross, dtype: int64

# %%
#top five most profitable diretor 
df.groupby('Director')['Gross'].sum().sort_values(ascending=False).head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='Director'>

# %%
#top five movies by imdb

df[['Series_Title','IMDB_Rating']].head(5)
# Out:
#                Series_Title  IMDB_Rating
# 0  The Shawshank Redemption          9.3
# 1             The Godfather          9.2
# 2           The Dark Knight          9.0
# 3    The Godfather: Part II          9.0
# 4              12 Angry Men          9.0

# %%
#top five movies by metasore

df.groupby('Series_Title')['Metascore'].sum().sort_values(ascending=False).head(5)
# Out:
# Series_Title
# The Godfather            100.0
# Casablanca               100.0
# Notorious                100.0
# Rear Window              100.0
# Trois couleurs: Rouge    100.0
# Name: Metascore, dtype: float64

# %%
#top five actor by IMDB 
df.groupby('Star1')['IMDB_Rating'].sum().sort_values(ascending=False).head(5)
# Out:
# Star1
# Tom Hanks            96.5
# Robert De Niro       88.8
# Al Pacino            80.1
# Clint Eastwood       79.7
# Leonardo DiCaprio    73.2
# Name: IMDB_Rating, dtype: float64

# %%
df.groupby(['Star1','Genre'])['Gross'].sum().sort_values(ascending=False).head(5)
# Out:
# Star1             Genre
# Joe Russo         Action       2205039403
# Daniel Radcliffe  Adventure    1533941837
# Toshirô Mifune    Action       1322908406
# Yun-Fat Chow      Action       1242855461
# Christian Bale    Action       1212088671
# Name: Gross, dtype: int64

# %%
# find number of movies done by each actor
df.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks             12
# Robert De Niro        11
# Clint Eastwood        10
# Al Pacino             10
# Leonardo DiCaprio      9
#                       ..
# Glen Hansard           1
# Giuseppe Battiston     1
# Giulietta Masina       1
# Gerardo Taracena       1
# Ömer Faruk Sorak       1
# Name: Series_Title, Length: 660, dtype: int64

# %%
#See outlier in Metascore
df['Metascore'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Metascore']<45]
# Out:
#                        Series_Title Released_Year  Runtime      Genre  \
# 356                  Tropa de Elite          2007      115     Action
# 648             The Boondock Saints          1999      108     Action
# 735                     Kai po che!          2013      130      Drama
# 788                        I Am Sam          2001      132      Drama
# 917                    Seven Pounds          2008      123      Drama
# 942            The Butterfly Effect          2004      113      Drama
# 957  Fear and Loathing in Las Vegas          1998      118  Adventure
#
#      IMDB_Rating          Director             Star1  No_of_Votes     Gross  \
# 356          8.0      José Padilha      Wagner Moura        98097      8060
# 648          7.8        Troy Duffy      Willem Dafoe       227143     25812
# 735          7.7   Abhishek Kapoor         Amit Sadh        32628   1122527
# 788          7.7     Jessie Nelson         Sean Penn       142863  40311852
# ...

# %%
#creaing one more column 

def rating(num):
    if num>7 and num<10:
        return "Excellent "
    elif num>4 and num<7:
        return "good movie"
    else:
        return "avg movie"

# %%
df['Movies Review']=df['IMDB_Rating'].apply(rating)

# %%
df
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes      Gross  \
# ...

# %%
#find excellent movies
n=df['Movies Review']=='Excellent'
new=df[n]
new[['Series_Title','Released_Year','Genre','Director']]
# Out:
#                  Series_Title Released_Year   Genre              Director
# 0    The Shawshank Redemption          1994   Drama        Frank Darabont
# 1               The Godfather          1972   Crime  Francis Ford Coppola
# 2             The Dark Knight          2008  Action     Christopher Nolan
# 3      The Godfather: Part II          1974   Crime  Francis Ford Coppola
# 4                12 Angry Men          1957   Crime          Sidney Lumet
# ..                        ...           ...     ...                   ...
# 995    Breakfast at Tiffany's          1961  Comedy         Blake Edwards
# 996                     Giant          1956   Drama        George Stevens
# 997     From Here to Eternity          1953   Drama        Fred Zinnemann
# 998                  Lifeboat          1944   Drama      Alfred Hitchcock
# 999              The 39 Steps          1935   Crime      Alfred Hitchcock
#
# [1000 rows x 4 columns]

# %%
df[['No_of_Votes','Metascore']].describe()
# Out:
#         No_of_Votes   Metascore
# count  1.000000e+03  843.000000
# mean   2.736929e+05   77.971530
# std    3.273727e+05   12.376099
# min    2.508800e+04   28.000000
# 25%    5.552625e+04   70.000000
# 50%    1.385485e+05   79.000000
# 75%    3.741612e+05   87.000000
# max    2.343110e+06  100.000000

# %%
df['No_of_Votes'].corr
# Out:
# <bound method Series.corr of 0      2343110
# 1      1620367
# 2      2303232
# 3      1129952
# 4       689845
#         ...
# 995     166544
# 996      34075
# 997      43374
# 998      26471
# 999      51853
# Name: No_of_Votes, Length: 1000, dtype: int64>

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\Sahil Vimal\AppData\Local\Temp\ipykernel_9476\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.pairplot(df)
